# %%
import numpy as np
import pandas as pd


features= list()
with open('features.txt') as f:
    features= [line.split()[1] for line in f.readlines()]
print('No. of Features : {}'.format(len(features)))
# Out:
# No. of Features : 561

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3904           0.268549          -0.043912          -0.171586
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3904         -0.002522           0.31921         -0.086625         -0.101835
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 3904          0.319096         -0.103809          0.450477  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 3904                    -0.052523                             -0.924942
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 3904                         -0.865342                             -0.619679
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 3904             -0.816363              0.207357              0.085047
#
#       subject  Activity  ActivityName
# 3904       19         1       WALKING
#
# [1 rows x 564 columns]

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 667           0.392325          -0.036101          -0.131429
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 667         -0.877155         -0.830771         -0.849993         -0.878166
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 667         -0.839183         -0.854768         -0.746747  ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 667                     0.328851                             -0.252124
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 667                         -0.077375                             -0.056973
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 667              0.734407             -0.062959              -0.93169
#
#      subject  Activity  ActivityName
# 667        9         6        LAYING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %%
# Checking for duplication

print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
# Checking for null value

print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

# %%
train.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %%
test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# # Save this dataframe in csv file

# %%
train.to_csv('csv_files/train.csv', index=False)
test.to_csv('csv_files/test.csv', index=False)

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.129s...
# [t-SNE] Computed neighbors for 7352 samples in 35.182s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635855
# [t-SNE] Computed conditional probabilities in 0.149s
# [t-SNE] Iteration 50: error = 124.7166672, gradient norm = 0.0237531 (50 iterations in 3.728s)
# [t-SNE] Iteration 100: error = 107.1667023, gradient norm = 0.0287170 (50 iterations in 2.267s)
# [t-SNE] Iteration 150: error = 100.9685211, gradient norm = 0.0193534 (50 iterations in 1.941s)
# [t-SNE] Iteration 200: error = 97.5479050, gradient norm = 0.0155654 (50 iterations in 1.799s)
# [t-SNE] Iteration 250: error = 95.2179108, gradient norm = 0.0125787 (50 iterations in 1.735s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.217911
# [t-SNE] Iteration 300: error = 4.1129460, gradient norm = 0.0015553 (50 iterations in 1.698s)
# [t-SNE] Iteration 350: error = 3.2058578, gradient norm = 0.0010077 (50 iterations in 1.720s)
# [t-SNE] Iteration 400: error = 2.7787154, gradient norm = 0.0007192 (50 iterations in 1.746s)
# [t-SNE] Iteration 450: error = 2.5149410, gradient norm = 0.0005697 (50 iterations in 1.773s)
# [t-SNE] Iteration 500: error = 2.3317373, gradient norm = 0.0004812 (50 iterations in 1.775s)
# [t-SNE] Iteration 550: error = 2.1941390, gradient norm = 0.0004151 (50 iterations in 1.782s)
# [t-SNE] Iteration 600: error = 2.0850556, gradient norm = 0.0003663 (50 iterations in 1.784s)
# [t-SNE] Iteration 650: error = 1.9953945, gradient norm = 0.0003330 (50 iterations in 1.787s)
# [t-SNE] Iteration 700: error = 1.9200267, gradient norm = 0.0003021 (50 iterations in 1.774s)
# [t-SNE] Iteration 750: error = 1.8552483, gradient norm = 0.0002766 (50 iterations in 1.774s)
# [t-SNE] Iteration 800: error = 1.7987357, gradient norm = 0.0002533 (50 iterations in 1.904s)
# [t-SNE] Iteration 850: error = 1.7487475, gradient norm = 0.0002397 (50 iterations in 2.085s)
# [t-SNE] Iteration 900: error = 1.7043028, gradient norm = 0.0002239 (50 iterations in 1.780s)
# [t-SNE] Iteration 950: error = 1.6642983, gradient norm = 0.0002089 (50 iterations in 1.779s)
# [t-SNE] Iteration 1000: error = 1.6280270, gradient norm = 0.0001979 (50 iterations in 1.779s)
# [t-SNE] KL divergence after 1000 iterations: 1.628027
# Done..
# Creating plot for this t-sne visualization..
# /home/captain/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.117s...
# [t-SNE] Computed neighbors for 7352 samples in 35.315s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.053s
# [t-SNE] Iteration 50: error = 114.0214310, gradient norm = 0.0197304 (50 iterations in 3.134s)
# [t-SNE] Iteration 100: error = 97.6387329, gradient norm = 0.0162174 (50 iterations in 2.161s)
# [t-SNE] Iteration 150: error = 93.2171631, gradient norm = 0.0098417 (50 iterations in 1.772s)
# [t-SNE] Iteration 200: error = 91.2295456, gradient norm = 0.0080987 (50 iterations in 1.746s)
# [t-SNE] Iteration 250: error = 90.0468750, gradient norm = 0.0043750 (50 iterations in 1.739s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.046875
# [t-SNE] Iteration 300: error = 3.5741718, gradient norm = 0.0014621 (50 iterations in 1.694s)
# [t-SNE] Iteration 350: error = 2.8144455, gradient norm = 0.0007507 (50 iterations in 1.704s)
# [t-SNE] Iteration 400: error = 2.4334252, gradient norm = 0.0005250 (50 iterations in 1.722s)
# [t-SNE] Iteration 450: error = 2.2156270, gradient norm = 0.0004035 (50 iterations in 1.737s)
# [t-SNE] Iteration 500: error = 2.0709937, gradient norm = 0.0003340 (50 iterations in 1.747s)
# [t-SNE] Iteration 550: error = 1.9657235, gradient norm = 0.0002839 (50 iterations in 1.747s)
# [t-SNE] Iteration 600: error = 1.8846083, gradient norm = 0.0002492 (50 iterations in 1.747s)
# [t-SNE] Iteration 650: error = 1.8193851, gradient norm = 0.0002187 (50 iterations in 1.746s)
# [t-SNE] Iteration 700: error = 1.7656965, gradient norm = 0.0001985 (50 iterations in 1.741s)
# [t-SNE] Iteration 750: error = 1.7203722, gradient norm = 0.0001819 (50 iterations in 1.744s)
# [t-SNE] Iteration 800: error = 1.6814321, gradient norm = 0.0001668 (50 iterations in 1.751s)
# [t-SNE] Iteration 850: error = 1.6476377, gradient norm = 0.0001543 (50 iterations in 1.842s)
# [t-SNE] Iteration 900: error = 1.6177511, gradient norm = 0.0001432 (50 iterations in 1.830s)
# [t-SNE] Iteration 950: error = 1.5913554, gradient norm = 0.0001345 (50 iterations in 1.799s)
# [t-SNE] Iteration 1000: error = 1.5676510, gradient norm = 0.0001252 (50 iterations in 1.809s)
# [t-SNE] KL divergence after 1000 iterations: 1.567651
# Done..
# Creating plot for this t-sne visualization..
# /home/captain/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.142s...
# [t-SNE] Computed neighbors for 7352 samples in 35.933s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.100s
# [t-SNE] Iteration 50: error = 105.7495422, gradient norm = 0.0205205 (50 iterations in 3.096s)
# [t-SNE] Iteration 100: error = 90.3196411, gradient norm = 0.0098461 (50 iterations in 2.112s)
# [t-SNE] Iteration 150: error = 87.2740555, gradient norm = 0.0051018 (50 iterations in 1.835s)
# [t-SNE] Iteration 200: error = 86.0570679, gradient norm = 0.0038194 (50 iterations in 1.858s)
# [t-SNE] Iteration 250: error = 85.3639145, gradient norm = 0.0034736 (50 iterations in 1.861s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.363914
# [t-SNE] Iteration 300: error = 3.1285999, gradient norm = 0.0013917 (50 iterations in 1.784s)
# [t-SNE] Iteration 350: error = 2.4857252, gradient norm = 0.0006467 (50 iterations in 1.748s)
# [t-SNE] Iteration 400: error = 2.1666045, gradient norm = 0.0004211 (50 iterations in 1.768s)
# [t-SNE] Iteration 450: error = 1.9826614, gradient norm = 0.0003144 (50 iterations in 1.775s)
# [t-SNE] Iteration 500: error = 1.8650093, gradient norm = 0.0002510 (50 iterations in 1.779s)
# [t-SNE] Iteration 550: error = 1.7820017, gradient norm = 0.0002114 (50 iterations in 1.794s)
# [t-SNE] Iteration 600: error = 1.7197151, gradient norm = 0.0001799 (50 iterations in 1.794s)
# [t-SNE] Iteration 650: error = 1.6714877, gradient norm = 0.0001593 (50 iterations in 1.794s)
# [t-SNE] Iteration 700: error = 1.6322471, gradient norm = 0.0001428 (50 iterations in 1.797s)
# [t-SNE] Iteration 750: error = 1.5995746, gradient norm = 0.0001310 (50 iterations in 1.815s)
# [t-SNE] Iteration 800: error = 1.5722176, gradient norm = 0.0001204 (50 iterations in 1.830s)
# [t-SNE] Iteration 850: error = 1.5489485, gradient norm = 0.0001082 (50 iterations in 1.822s)
# [t-SNE] Iteration 900: error = 1.5287484, gradient norm = 0.0001026 (50 iterations in 1.806s)
# [t-SNE] Iteration 950: error = 1.5113667, gradient norm = 0.0000983 (50 iterations in 1.804s)
# [t-SNE] Iteration 1000: error = 1.4963117, gradient norm = 0.0000913 (50 iterations in 1.814s)
# [t-SNE] KL divergence after 1000 iterations: 1.496312
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# /home/captain/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.133s...
# [t-SNE] Computed neighbors for 7352 samples in 36.539s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.194s
# [t-SNE] Iteration 50: error = 97.7396774, gradient norm = 0.0172005 (50 iterations in 7.057s)
# [t-SNE] Iteration 100: error = 84.1471100, gradient norm = 0.0066381 (50 iterations in 2.647s)
# [t-SNE] Iteration 150: error = 81.9306488, gradient norm = 0.0039787 (50 iterations in 2.239s)
# [t-SNE] Iteration 200: error = 81.1585312, gradient norm = 0.0023992 (50 iterations in 2.226s)
# [t-SNE] Iteration 250: error = 80.7636414, gradient norm = 0.0021665 (50 iterations in 2.239s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.763641
# [t-SNE] Iteration 300: error = 2.6936288, gradient norm = 0.0012964 (50 iterations in 2.073s)
# [t-SNE] Iteration 350: error = 2.1613162, gradient norm = 0.0005736 (50 iterations in 1.914s)
# [t-SNE] Iteration 400: error = 1.9118180, gradient norm = 0.0003472 (50 iterations in 1.923s)
# [t-SNE] Iteration 450: error = 1.7660817, gradient norm = 0.0002455 (50 iterations in 1.939s)
# [t-SNE] Iteration 500: error = 1.6723946, gradient norm = 0.0001921 (50 iterations in 1.951s)
# [t-SNE] Iteration 550: error = 1.6082526, gradient norm = 0.0001564 (50 iterations in 1.956s)
# [t-SNE] Iteration 600: error = 1.5618057, gradient norm = 0.0001357 (50 iterations in 1.970s)
# [t-SNE] Iteration 650: error = 1.5264304, gradient norm = 0.0001162 (50 iterations in 1.988s)
# [t-SNE] Iteration 700: error = 1.4988536, gradient norm = 0.0001030 (50 iterations in 1.986s)
# [t-SNE] Iteration 750: error = 1.4768595, gradient norm = 0.0000946 (50 iterations in 1.991s)
# [t-SNE] Iteration 800: error = 1.4589200, gradient norm = 0.0000865 (50 iterations in 2.002s)
# [t-SNE] Iteration 850: error = 1.4444600, gradient norm = 0.0000817 (50 iterations in 1.997s)
# [t-SNE] Iteration 900: error = 1.4325434, gradient norm = 0.0000750 (50 iterations in 2.005s)
# [t-SNE] Iteration 950: error = 1.4223177, gradient norm = 0.0000726 (50 iterations in 2.004s)
# [t-SNE] Iteration 1000: error = 1.4134755, gradient norm = 0.0000703 (50 iterations in 2.003s)
# [t-SNE] KL divergence after 1000 iterations: 1.413476
# Done..
# Creating plot for this t-sne visualization..
# /home/captain/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.126s...
# [t-SNE] Computed neighbors for 7352 samples in 37.739s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.472s
# [t-SNE] Iteration 50: error = 84.2424927, gradient norm = 0.0347276 (50 iterations in 5.590s)
# [t-SNE] Iteration 100: error = 75.6191483, gradient norm = 0.0041176 (50 iterations in 4.166s)
# [t-SNE] Iteration 150: error = 74.5861435, gradient norm = 0.0022801 (50 iterations in 3.167s)
# [t-SNE] Iteration 200: error = 74.2307129, gradient norm = 0.0015354 (50 iterations in 3.166s)
# [t-SNE] Iteration 250: error = 74.0513687, gradient norm = 0.0010282 (50 iterations in 3.190s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.051369
# [t-SNE] Iteration 300: error = 2.1548555, gradient norm = 0.0011957 (50 iterations in 2.760s)
# [t-SNE] Iteration 350: error = 1.7578940, gradient norm = 0.0004883 (50 iterations in 2.397s)
# [t-SNE] Iteration 400: error = 1.5900624, gradient norm = 0.0002796 (50 iterations in 2.371s)
# [t-SNE] Iteration 450: error = 1.4964222, gradient norm = 0.0001888 (50 iterations in 2.386s)
# [t-SNE] Iteration 500: error = 1.4365095, gradient norm = 0.0001415 (50 iterations in 2.398s)
# [t-SNE] Iteration 550: error = 1.3953278, gradient norm = 0.0001113 (50 iterations in 2.401s)
# [t-SNE] Iteration 600: error = 1.3657070, gradient norm = 0.0000941 (50 iterations in 2.410s)
# [t-SNE] Iteration 650: error = 1.3442019, gradient norm = 0.0000824 (50 iterations in 2.418s)
# [t-SNE] Iteration 700: error = 1.3283379, gradient norm = 0.0000723 (50 iterations in 2.431s)
# [t-SNE] Iteration 750: error = 1.3163292, gradient norm = 0.0000683 (50 iterations in 2.432s)
# [t-SNE] Iteration 800: error = 1.3073431, gradient norm = 0.0000634 (50 iterations in 2.433s)
# [t-SNE] Iteration 850: error = 1.3002975, gradient norm = 0.0000605 (50 iterations in 2.440s)
# [t-SNE] Iteration 900: error = 1.2950393, gradient norm = 0.0000613 (50 iterations in 2.452s)
# [t-SNE] Iteration 950: error = 1.2913829, gradient norm = 0.0000564 (50 iterations in 2.448s)
# [t-SNE] Iteration 1000: error = 1.2879887, gradient norm = 0.0000518 (50 iterations in 2.455s)
# [t-SNE] KL divergence after 1000 iterations: 1.287989
# Done..
# Creating plot for this t-sne visualization..
# /home/captain/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %%
# get X_train and y_train from csv files
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# %%
# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

# %%
print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True, \
                 print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %%
from sklearn import linear_model
from sklearn import metrics

from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  1.1min finished
# /home/captain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/captain/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:01:15.132914
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.008074
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9630132337970818
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 428  57   0   0   4]
#  [  0  11 520   1   0   0]
#  [  0   0   0 495   1   0]
#  [  0   0   0   3 409   8]
#  [  0   0   0  22   0 449]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.95      1.00      0.97       496
# WALKING_DOWNSTAIRS       1.00      0.97      0.99       420
#   WALKING_UPSTAIRS       0.97      0.95      0.96       471
#
#          micro avg       0.96      0.96      0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
# observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LogisticRegression(C=30, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 30, 'penalty': 'l2'}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 3
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9461371055495104
